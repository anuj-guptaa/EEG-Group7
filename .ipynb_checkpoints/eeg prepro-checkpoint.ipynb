# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.io

# %%
mat = scipy.io.loadmat("EEG-data/Subject1_1D.mat")
mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Sat Jan 27 10:48:51 2007',
#  '__version__': '1.0',
#  '__globals__': [],
#  'readme': array(['This subject is a 21 year old, right handed male with no known medical conditions. The EEG consists of actual random movements of left and right hand recorded with eyes closed. Each row represents one electrode. The order of the electrodes is FP1 FP2 F3 F4 C3 C4 P3 P4 O1 O2 F7 F8 T3 T4 T5 T6 FZ CZ PZ. The recording was done at 500Hz using Neurofax EEG System which uses a daisy chain montage. The data was exported with a common reference using Eemagine EEG. AC Lines in this country work at 50 Hz. For further information, please contact midhatali@gmail.com'],
#        dtype='<U560'),
#  'left': array([[  -5.078,  -17.48 ,    2.051, ...,  -59.277,  -59.668,  -60.254],
#         [  -5.078,  -18.359,  -11.426, ..., -291.016, -291.504, -270.703],
#         [   7.91 ,   -8.203,   32.129, ...,  -25.391,  -20.117,  -26.172],
#         ...,
#         [  -6.055,  -17.773,    1.66 , ...,   33.008,   31.055,   34.375],
#         [  -7.91 ,  -10.742,    2.344, ..., -149.316, -148.926, -141.113],
#         [  -3.809,   -9.766,    2.344, ...,   69.727,   72.559,   79.59 ]]),
#  'right': array([[  -5.762,  -10.254,  -16.309, ..., -198.73 , -212.207, -214.941],
#         [   0.586,  -16.992,  -25.293, ..., -373.242, -378.711, -382.91 ],
#         [   1.855,   -9.082,  -12.695, ...,  -11.133,  -36.035,  -26.855],
#         ...,
#         [  -3.613,   -4.395,   -6.445, ...,  -99.707, -117.969, -121.094],
#         [  -4.688,  -10.937,  -20.605, ..., -220.508, -232.52 , -237.207],
#         [   2.734,    0.684,  -10.254, ...,  112.891,  103.125,  100.391]]),
#  'baseline': array([[ -41.016,   -9.375,   -1.172, ..., -271.582, -274.707, -282.227],
#         [ -20.605,   -4.492,   11.23 , ..., -324.512, -322.852, -324.121],
#         [ -36.523,  -30.078,   -7.715, ...,   97.266,   93.555,   86.133],
#         ...,
#         [ -31.641,    0.   ,    2.441, ...,  -67.383,  -74.121,  -82.227],
#         [ -17.578,    2.441,   12.402, ..., -263.379, -269.043, -278.418],
#         [ -12.207,   10.352,   19.434, ...,   92.285,   90.43 ,   78.809]])}

# %%
numpy_left = mat['left']
numpy_right = mat['right']

numpy_left = numpy_left.reshape(-1,19)
numpy_right = numpy_right.reshape(-1,19)

left = pd.DataFrame(numpy_left, columns=['FP1', 'FP2', 'F3', 'F4', 
                                          'C3', 'C4', 'P3', 'P4', 
                                          'O1', 'O2', 'F7', 'F8', 
                                          'T3', 'T4', 'T5', 'T6', 
                                          'FZ', 'CZ', 'PZ'])

right = pd.DataFrame(numpy_right, columns=['FP1', 'FP2', 'F3', 'F4', 
                                          'C3', 'C4', 'P3', 'P4', 
                                          'O1', 'O2', 'F7', 'F8', 
                                          'T3', 'T4', 'T5', 'T6', 
                                          'FZ', 'CZ', 'PZ'])

# %%
left
# Out:
#           FP1     FP2      F3      F4      C3      C4      P3      P4  \
# 0      -5.078 -17.480   2.051  31.152  37.500  28.320  15.137   5.566
# 1      -6.445  -4.785  -3.906   7.324  17.676  22.363  16.602   6.445
# 2     -12.988 -14.355 -12.598  -7.910  16.895  18.555  29.199  37.988
# 3      23.340  11.035   5.664   5.566  -3.418  -2.539  16.602  31.543
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 64295  125.195  129.297  122.852  124.219  124.805  117.383  112.500  112.012
# 64296  112.500  116.602  126.074  122.266  121.289  106.250   98.828   96.875
# 64297  108.105  115.234  125.293  131.738  131.641  126.855  112.109  107.227
# 64298  114.355  115.625  115.918  122.461  129.980  126.660  124.609  114.160
# 64299   97.754  101.563  100.293   96.387  117.676  126.855  126.172  123.340
#
#             FZ       CZ       PZ
# 0      -20.215  -19.727   -8.008
# 1      -32.129  -33.887  -25.781
# 2      -17.969  -22.559  -18.652
# 3      -28.320  -25.391  -33.008
# 4       -3.027    1.465   -5.273
# ...        ...      ...      ...
# 64295  114.258  124.121  128.027
# 64296  106.934  110.449  115.039
# 64297  106.250  109.668  114.453
# 64298  104.102   96.094   99.121
# 64299  112.891  103.125  100.391
#
# [64300 rows x 19 columns]

# %% [markdown]
# "The order of the electrodes is FP1 FP2 F3 F4 C3 C4 P3 P4 O1 O2 F7 F8 T3 T4 T5 T6 FZ CZ PZ."

# %% [markdown]
# Channels C3, C4, and CZ are usually associated with voluntary movements.

# %%
left_channels = left[["C3", "C4", "CZ"]]
right_channels = right[["C3", "C4", "CZ"]]

# %%
left_channels
# Out:
#            C3      C4      CZ
# 0      37.500  28.320  10.254
# 1      17.676  22.363  30.469
# 2      16.895  18.555  24.121
# 3      -3.418  -2.539  32.227
# 4       3.027   2.930  15.723
# ...       ...     ...     ...
# 64295  81.445  85.449  92.969
# 64296  86.719  87.598  93.750
# 64297  72.266  80.078  83.301
# 64298  69.922  70.312  81.641
# 64299  92.578  79.980  72.559
#
# [64300 rows x 3 columns]

# %%
right_channels
# Out:
#             C3       C4       CZ
# 0      -35.156  -38.477  -19.727
# 1      -26.855  -39.160  -33.887
# 2        3.320  -15.820  -22.559
# 3        2.246  -10.937  -25.391
# 4       -9.082  -11.328    1.465
# ...        ...      ...      ...
# 64295   98.438  107.520  124.121
# 64296  102.246   98.730  110.449
# 64297  113.867  105.469  109.668
# 64298  135.352  122.266   96.094
# 64299  119.629  123.926  103.125
#
# [64300 rows x 3 columns]

# %%
import mne
from mne import create_info
from mne.io import RawArray

# %%
list(left.columns)
# Out:
# ['FP1',
#  'FP2',
#  'F3',
#  'F4',
#  'C3',
#  'C4',
#  'P3',
#  'P4',
#  'O1',
#  'O2',
#  'F7',
#  'F8',
#  'T3',
#  'T4',
#  'T5',
#  'T6',
#  'FZ',
#  'CZ',
#  'PZ']

# %%
(len(left) - 1)
# Out:
# 64299

# %%
sfreq = 125
ch_names = ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6','FZ', 'CZ', 'PZ']
ch_types = ['eeg'] * (len(left.columns) - 1) + ['stim']
ten_twenty_montage = mne.channels.make_standard_montage('standard_1020')

left = left.T  #mne looks at the tranpose() format
left[:-1] *= 1e-6  #convert from uVolts to Volts (mne assumes Volts data)

info = create_info(ch_names=ch_names, ch_types=ch_types, sfreq=sfreq)

raw = mne.io.RawArray(left, info)
# raw.set_montage(ten_twenty_montage)
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=64300
#     Range : 0 ... 64299 =      0.000 ...   514.392 secs
# Ready.

# %%
raw.plot_psd()
# Out:
# Effective window size : 16.384 (s)
# C:\Users\anujg\AppData\Local\Temp/ipykernel_15424/2847632005.py:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd()
# <MNELineFigure size 720x252 with 1 Axes>
# <MNELineFigure size 720x252 with 1 Axes>
